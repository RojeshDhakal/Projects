# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('../DATA/AAPLStocks.xlsx',parse_dates=True)
data.drop('Unnamed: 0', axis=1, inplace=True)
#data['date']= pd.to_datetime(data[['Year', 'month','day']])
#data.set_index('date', inplace=True)
#data.drop(['Year', 'month','day'], axis=1,inplace=True)
data
# Out:
#             Open        High         Low       Close     Volume  Dividends  \
# 0       0.147936    0.148888    0.143180    0.147936  146440000        0.0
# 1       0.146034    0.149839    0.144607    0.145558  112235200        0.0
# 2       0.146034    0.147461    0.141753    0.146034  151121600        0.0
# 3       0.144131    0.145558    0.140802    0.140802  211881600        0.0
# 4       0.139374    0.143655    0.138898    0.139374  162444800        0.0
# ...          ...         ...         ...         ...        ...        ...
# 6287  134.080002  136.250000  133.770004  135.270004   58280400        0.0
# 6288  135.279999  138.020004  134.220001  137.869995   79972200        0.0
# 6289  138.119995  143.320007  137.899994  141.110001   81760300        0.0
# 6290  140.309998  143.160004  140.300003  142.529999   66435100        0.0
# 6291  140.889999  142.429993  138.809998  141.860001   65652500        0.0
#
#       Stock Splits  Year  month  day
# ...

# %%
df=data[data['Close']>78]
df=df[['Close','Year','month','day']]
df['date']= pd.to_datetime(data[['Year', 'month','day']],)
df.set_index('date', inplace=True)
df.drop(['Year', 'month','day'], axis=1,inplace=True)
df
# Out:
#                  Close
# date
# 2020-01-17   78.063148
# 2020-01-23   78.185600
# 2020-01-29   79.437141
# 2020-01-30   79.322037
# 2020-02-04   78.092545
# ...                ...
# 2023-01-19  135.270004
# 2023-01-20  137.869995
# 2023-01-23  141.110001
# 2023-01-24  142.529999
# 2023-01-25  141.860001
#
# [690 rows x 1 columns]

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(df.Close)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_data, test_data = df_log[3:int(len(df_log)*0.9)], df_log[int(len(df_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_log, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm
import pmdarima as pm

# %%
model_autoARIMA = pm.auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
model_autoARIMA.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-3074.199, Time=0.51 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-3073.451, Time=0.23 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-3073.503, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-3074.949, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-3071.309, Time=0.36 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.593 seconds
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  618
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                1538.475
# Date:                Wed, 15 Feb 2023   AIC                          -3074.949
# Time:                        20:17:25   BIC                          -3070.524
# Sample:                             0   HQIC                         -3073.229
#                                 - 618
# Covariance Type:                  opg
# ...

# %%
model = ARIMA(train_data, order=(0,1,0))  
fitted = model.fit()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                  618
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                1538.475
# Date:                Wed, 15 Feb 2023   AIC                          -3074.949
# Time:                        20:30:14   BIC                          -3070.524
# Sample:                             0   HQIC                         -3073.229
#                                 - 618
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0004   1.69e-05     23.602      0.000       0.000       0.000
# ...
# Ljung-Box (L1) (Q):                   1.25   Jarque-Bera (JB):                70.79
# Prob(Q):                              0.26   Prob(JB):                         0.00
# ...

# %%
step=30

# %%
forecast_result = fitted.forecast(step)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
fc, se, conf = fitted.forecast(step)[:3]
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
fc
# Out:
# 4.928346081969286

# %%
se
# Out:
# 4.928346081969286

# %%
conf
# Out:
# 4.928346081969286

# %%
start=len(train_data)
end= len(train_data)+len(test_data)-1

# %%
pred= fitted.predict(start=start, end=end, type='levels')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
print(pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12968\1744510300.py in <module>
# ----> 1 print(pred)
#
# TypeError: 'Series' object is not callable

# %%
pred.index=df.index[start:end+1]

# %%
pred
# Out:
# date
# 2022-10-12    4.928346
# 2022-10-13    4.928346
# 2022-10-14    4.928346
# 2022-10-17    4.928346
# 2022-10-18    4.928346
#                 ...
# 2023-01-13    4.928346
# 2023-01-17    4.928346
# 2023-01-18    4.928346
# 2023-01-19    4.928346
# 2023-01-20    4.928346
# Name: predicted_mean, Length: 69, dtype: float64

# %%
n=int(len(df)*0.8)
train=df.Close[:n]
test=df.Close[n:]

# %%
train
# Out:
# date
# 2020-01-17     78.063148
# 2020-01-23     78.185600
# 2020-01-29     79.437141
# 2020-01-30     79.322037
# 2020-02-04     78.092545
#                  ...
# 2022-07-01    138.507507
# 2022-07-05    141.129517
# 2022-07-06    142.485397
# 2022-07-07    145.904968
# 2022-07-08    146.592850
# Name: Close, Length: 552, dtype: float64

# %%
model=ARIMA(train,order=(0,1,0))
result=model.fit()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                  552
# Model:                 ARIMA(0, 1, 0)   Log Likelihood               -1320.340
# Date:                Wed, 15 Feb 2023   AIC                           2642.680
# Time:                        20:40:37   BIC                           2646.992
# Sample:                             0   HQIC                          2644.365
#                                 - 552
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         7.0614      0.332     21.246      0.000       6.410       7.713
# ...
# Ljung-Box (L1) (Q):                   0.30   Jarque-Bera (JB):                42.31
# Prob(Q):                              0.59   Prob(JB):                         0.00
# ...

# %%
step=300
fc, se, _ = result.forecast(step)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19372\3789825993.py in <module>
#       1 step=300
# ----> 2 fc, se, _ = result.forecast(step)
#
# ValueError: too many values to unpack (expected 3)

# %%
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19372\2813052891.py in <module>
# ----> 1 fc, se, conf= result.forecast(step)
#
# ValueError: too many values to unpack (expected 3)

# %%
df['diff']= df['Close'].diff()

# %%
df
# Out:
#                  Close      diff
# date
# 2020-01-17   78.063148       NaN
# 2020-01-23   78.185600  0.122452
# 2020-01-29   79.437141  1.251541
# 2020-01-30   79.322037 -0.115105
# 2020-02-04   78.092545 -1.229492
# ...                ...       ...
# 2023-01-19  135.270004  0.059998
# 2023-01-20  137.869995  2.599991
# 2023-01-23  141.110001  3.240005
# 2023-01-24  142.529999  1.419998
# 2023-01-25  141.860001 -0.669998
#
# [690 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
df['diff'].value_counts()
# Out:
#  0.000000    2
#  1.823975    2
#  0.580002    2
# -1.911362    1
# -3.653458    1
#             ..
#  2.226639    1
#  0.841171    1
#  2.869888    1
#  0.306778    1
# -0.669998    1
# Name: diff, Length: 686, dtype: int64

# %%
model=ARIMA(df.Close,order=(0,1,0))
result=model.fit()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                  689
# Model:                 ARIMA(0, 1, 0)   Log Likelihood               -1679.920
# Date:                Wed, 15 Feb 2023   AIC                           3361.841
# Time:                        21:44:41   BIC                           3366.375
# Sample:                             0   HQIC                          3363.595
#                                 - 689
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         7.7339      0.315     24.541      0.000       7.116       8.352
# ...
# Ljung-Box (L1) (Q):                   0.60   Jarque-Bera (JB):                65.09
# Prob(Q):                              0.44   Prob(JB):                         0.00
# ...

# %%
step=300
fc= result.forecast(step)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
conf_int = result.conf_int(alpha=0.05)

# %%
conf_int
# Out:
#                0         1
# sigma2  7.116218  8.351523

# %%
fc=pd.Series(fc, index=test[:step].index)
lower=pd.Series(conf_int[:,0],index=test[:step].index)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19372\1988010068.py in <module>
#       1 fc=pd.Series(fc, index=test[:step].index)
# ----> 2 lower=pd.Series(conf_int[:,0])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             self._check_indexing_error(key)
#     389             raise KeyError(key)
# ...

# %%
forecast, stderr, conf_int = result.forecast(steps=10, alpha=0.05)

# Print standard errors of forecasted values
print("Standard errors of forecasted values:", stderr)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19372\3744679732.py in <module>
# ----> 1 forecast, stderr, conf_int = result.forecast(steps=10, alpha=0.05)
#       2
#       3 # Print standard errors of forecasted values
#       4 print("Standard errors of forecasted values:", stderr)
#
# ValueError: too many values to unpack (expected 3)

# %%
conf
# Out:
# 141.8600006103516

# %%
result.plot_predict(start=1,stop=60,dynamic=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19372\833530630.py in <module>
# ----> 1 result.plot_predict(start=1,stop=60,dynamic=True)
#
# ~\anaconda3\lib\site-packages\statsmodels\base\wrapper.py in __getattribute__(self, attr)
#      32             pass
#      33
# ---> 34         obj = getattr(results, attr)
#      35         data = results.model.data
#      36         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'ARIMAResults' object has no attribute 'plot_predict'

# %%
pred = result.predict(start=150, end=300, dynamic=True)

# %%
plt.figure(figsize=(10,8))
plt.plot(df.Close, label='actual')
plt.plot(pred, label='predicted')
plt.legend()
plt.show()
