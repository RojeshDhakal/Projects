# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.linear_model import Lasso, LassoCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Importing data which have been extracted by using yfinance which is in API Apple Data

# %%
data=pd.read_excel('../DATA/AAPLStocks.xlsx')

# %%
data
# Out:
#       Unnamed: 0        Open        High         Low       Close     Volume  \
# 0              0    0.147936    0.148888    0.143180    0.147936  146440000
# 1              1    0.146034    0.149839    0.144607    0.145558  112235200
# 2              2    0.146034    0.147461    0.141753    0.146034  151121600
# 3              3    0.144131    0.145558    0.140802    0.140802  211881600
# 4              4    0.139374    0.143655    0.138898    0.139374  162444800
# ...          ...         ...         ...         ...         ...        ...
# 6287        6287  134.080002  136.250000  133.770004  135.270004   58280400
# 6288        6288  135.279999  138.020004  134.220001  137.869995   79972200
# 6289        6289  138.119995  143.320007  137.899994  141.110001   81760300
# 6290        6290  140.309998  143.160004  140.300003  142.529999   66435100
# 6291        6291  140.889999  142.429993  138.809998  141.860001   65652500
#
#       Dividends  Stock Splits  Year  month  day
# 0           0.0             0  1998      1   26
# 1           0.0             0  1998      1   27
# 2           0.0             0  1998      1   28
# 3           0.0             0  1998      1   29
# 4           0.0             0  1998      1   30
# ...         ...           ...   ...    ...  ...
# 6287        0.0             0  2023      1   19
# 6288        0.0             0  2023      1   20
# 6289        0.0             0  2023      1   23
# 6290        0.0             0  2023      1   24
# 6291        0.0             0  2023      1   25
#
# [6292 rows x 11 columns]

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data
# Out:
#             Open        High         Low       Close     Volume  Dividends  \
# 0       0.147936    0.148888    0.143180    0.147936  146440000        0.0
# 1       0.146034    0.149839    0.144607    0.145558  112235200        0.0
# 2       0.146034    0.147461    0.141753    0.146034  151121600        0.0
# 3       0.144131    0.145558    0.140802    0.140802  211881600        0.0
# 4       0.139374    0.143655    0.138898    0.139374  162444800        0.0
# ...          ...         ...         ...         ...        ...        ...
# 6287  134.080002  136.250000  133.770004  135.270004   58280400        0.0
# 6288  135.279999  138.020004  134.220001  137.869995   79972200        0.0
# 6289  138.119995  143.320007  137.899994  141.110001   81760300        0.0
# 6290  140.309998  143.160004  140.300003  142.529999   66435100        0.0
# 6291  140.889999  142.429993  138.809998  141.860001   65652500        0.0
#
#       Stock Splits  Year  month  day
# 0                0  1998      1   26
# 1                0  1998      1   27
# 2                0  1998      1   28
# 3                0  1998      1   29
# 4                0  1998      1   30
# ...            ...   ...    ...  ...
# 6287             0  2023      1   19
# 6288             0  2023      1   20
# 6289             0  2023      1   23
# 6290             0  2023      1   24
# 6291             0  2023      1   25
#
# [6292 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# Year            0
# month           0
# day             0
# dtype: int64

# %%
data.dtypes
# Out:
# Open            float64
# High            float64
# Low             float64
# Close           float64
# Volume            int64
# Dividends       float64
# Stock Splits      int64
# Year              int64
# month             int64
# day               int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6292 entries, 0 to 6291
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          6292 non-null   float64
#  1   High          6292 non-null   float64
#  2   Low           6292 non-null   float64
#  3   Close         6292 non-null   float64
#  4   Volume        6292 non-null   int64
#  5   Dividends     6292 non-null   float64
#  6   Stock Splits  6292 non-null   int64
#  7   Year          6292 non-null   int64
#  8   month         6292 non-null   int64
#  9   day           6292 non-null   int64
# dtypes: float64(5), int64(5)
# memory usage: 491.7 KB

# %%
data['date']= pd.to_datetime(data[['Year', 'month','day']])

# %%
data
# Out:
#             Open        High         Low       Close     Volume  Dividends  \
# 0       0.147936    0.148888    0.143180    0.147936  146440000        0.0
# 1       0.146034    0.149839    0.144607    0.145558  112235200        0.0
# 2       0.146034    0.147461    0.141753    0.146034  151121600        0.0
# 3       0.144131    0.145558    0.140802    0.140802  211881600        0.0
# 4       0.139374    0.143655    0.138898    0.139374  162444800        0.0
# ...          ...         ...         ...         ...        ...        ...
# 6287  134.080002  136.250000  133.770004  135.270004   58280400        0.0
# 6288  135.279999  138.020004  134.220001  137.869995   79972200        0.0
# 6289  138.119995  143.320007  137.899994  141.110001   81760300        0.0
# 6290  140.309998  143.160004  140.300003  142.529999   66435100        0.0
# 6291  140.889999  142.429993  138.809998  141.860001   65652500        0.0
#
#       Stock Splits  Year  month  day       date
# 0                0  1998      1   26 1998-01-26
# 1                0  1998      1   27 1998-01-27
# 2                0  1998      1   28 1998-01-28
# 3                0  1998      1   29 1998-01-29
# 4                0  1998      1   30 1998-01-30
# ...            ...   ...    ...  ...        ...
# 6287             0  2023      1   19 2023-01-19
# 6288             0  2023      1   20 2023-01-20
# 6289             0  2023      1   23 2023-01-23
# 6290             0  2023      1   24 2023-01-24
# 6291             0  2023      1   25 2023-01-25
#
# [6292 rows x 11 columns]

# %%
data.set_index('date', inplace=True)

# %%
data.drop(['Year', 'month','day'], axis=1,inplace=True)

# %%
data.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  6292.000000  6292.000000  6292.000000  6292.000000  6.292000e+03
# mean     26.814686    27.121171    26.512570    26.828094  4.198843e+08
# std      42.284471    42.807039    41.777509    42.312058  3.853638e+08
# min       0.134617     0.140802     0.132239     0.134617  3.519590e+07
# 25%       0.795188     0.822094     0.767509     0.789390  1.496880e+08
# 50%       7.932815     8.011357     7.828543     7.915763  3.073726e+08
# 75%      28.724533    28.940814    28.490394    28.689248  5.571797e+08
# max     181.576172   181.884380   178.086416   180.959732  7.421641e+09
#
#          Dividends  Stock Splits
# count  6292.000000   6292.000000
# mean      0.001081      0.002384
# std       0.013650      0.107695
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       0.230000      7.000000

# %%
data.corr().T
# Out:
#                   Open      High       Low     Close    Volume  Dividends  \
# Open          1.000000  0.999930  0.999912  0.999813 -0.416959   0.082621
# High          0.999930  1.000000  0.999898  0.999912 -0.416183   0.082066
# Low           0.999912  0.999898  1.000000  0.999915 -0.418064   0.082378
# Close         0.999813  0.999912  0.999915  1.000000 -0.417129   0.082302
# Volume       -0.416959 -0.416183 -0.418064 -0.417129  1.000000  -0.054751
# Dividends     0.082621  0.082066  0.082378  0.082302 -0.054751   1.000000
# Stock Splits  0.008730  0.009002  0.008722  0.008979 -0.003832  -0.001753
#
#               Stock Splits
# Open              0.008730
# High              0.009002
# Low               0.008722
# Close             0.008979
# Volume           -0.003832
# Dividends        -0.001753
# Stock Splits      1.000000

# %%
data.plot(subplots=True, figsize=(15,7))
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(30,15))
ax.plot(data['Close'], color='g')
ax.set_xlabel("Date", fontsize=15)
ax.set_ylabel("Price", fontsize=15)
ax.set_title("Closing Price of Apple (1998-2023)", fontsize=20)
plt.grid()
plt.show()
fig.savefig('Closing_price.png')

# %%
plt.plot(data.Volume)
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Volume traded of Apple')
plt.grid()
plt.show()

# %%
plt.boxplot(data.Volume)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2005850cbe0>,
#   <matplotlib.lines.Line2D at 0x2005850c5e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2005850ca30>,
#   <matplotlib.lines.Line2D at 0x20058e90700>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2005850cd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2005604ed60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20051e5cc10>],
#  'means': []}

# %%
sub_df=data[data['Open']>100]

# %%
sub_df
# Out:
#                   Open        High         Low       Close     Volume  \
# date
# 2020-07-31  101.306835  104.782687   99.278429  104.630066  374336800
# 2020-08-03  106.540297  109.925068  106.237518  107.266487  308151200
# 2020-08-04  107.458493  109.090570  106.724918  107.982826  173071600
# 2020-08-05  107.699732  108.699162  107.227091  108.374222  121776800
# 2020-08-06  108.711478  112.657506  108.113298  112.155327  202428800
# ...                ...         ...         ...         ...        ...
# 2023-01-19  134.080002  136.250000  133.770004  135.270004   58280400
# 2023-01-20  135.279999  138.020004  134.220001  137.869995   79972200
# 2023-01-23  138.119995  143.320007  137.899994  141.110001   81760300
# 2023-01-24  140.309998  143.160004  140.300003  142.529999   66435100
# 2023-01-25  140.889999  142.429993  138.809998  141.860001   65652500
#
#             Dividends  Stock Splits
# date
# 2020-07-31        0.0             0
# 2020-08-03        0.0             0
# 2020-08-04        0.0             0
# 2020-08-05        0.0             0
# 2020-08-06        0.0             0
# ...               ...           ...
# 2023-01-19        0.0             0
# 2023-01-20        0.0             0
# 2023-01-23        0.0             0
# 2023-01-24        0.0             0
# 2023-01-25        0.0             0
#
# [626 rows x 7 columns]

# %% [markdown]
# EDA for open and close price of Apple Stock

# %%
sns.countplot(y=data.dtypes ,data=data)
# Out:
# <AxesSubplot:xlabel='count'>

# %%
data.hist(figsize=(10,15))
plt.show()

# %%
import matplotlib.dates as mdates

# %%
fig=plt.figure(figsize=(10,10))
plt.plot(sub_df.Open, marker='.')
plt.plot(sub_df.Close, marker='x')
plt.legend(['O','C'])
plt.title('Opening and cLosing price of Apple')
plt.xlabel('Year')
plt.ylabel('Price')
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
xfmt = mdates.DateFormatter("%Y-%m")
plt.gca().xaxis.set_major_formatter(xfmt)
fig.savefig('Open-Close.png')

# %%
data.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %% [markdown]
# Pairplot of Target Variable with Independent Variable

# %%
target_col = 'Close'
feature_cols = [c for c in data.columns if c != target_col]

X =  data[feature_cols]
y = data[target_col]

# %%
plt.figure(figsize=(25, 25))
for i, col in enumerate(X):
    plt.subplot(4, 4 , i+1)
    sns.regplot(x=col, y=y, data=data)
    plt.title("%s vs Close" %(col))

# %%
sns.pairplot(data=data, kind='reg')

# %% [markdown]
# ## Looking for investment over time

# %%
df= data.copy()

# %%
df
# Out:
#                   Open        High         Low       Close     Volume  \
# date
# 1998-01-26    0.147936    0.148888    0.143180    0.147936  146440000
# 1998-01-27    0.146034    0.149839    0.144607    0.145558  112235200
# 1998-01-28    0.146034    0.147461    0.141753    0.146034  151121600
# 1998-01-29    0.144131    0.145558    0.140802    0.140802  211881600
# 1998-01-30    0.139374    0.143655    0.138898    0.139374  162444800
# ...                ...         ...         ...         ...        ...
# 2023-01-19  134.080002  136.250000  133.770004  135.270004   58280400
# 2023-01-20  135.279999  138.020004  134.220001  137.869995   79972200
# 2023-01-23  138.119995  143.320007  137.899994  141.110001   81760300
# 2023-01-24  140.309998  143.160004  140.300003  142.529999   66435100
# 2023-01-25  140.889999  142.429993  138.809998  141.860001   65652500
#
#             Dividends  Stock Splits
# date
# 1998-01-26        0.0             0
# 1998-01-27        0.0             0
# 1998-01-28        0.0             0
# 1998-01-29        0.0             0
# 1998-01-30        0.0             0
# ...               ...           ...
# 2023-01-19        0.0             0
# 2023-01-20        0.0             0
# 2023-01-23        0.0             0
# 2023-01-24        0.0             0
# 2023-01-25        0.0             0
#
# [6292 rows x 7 columns]

# %%
df.reset_index(inplace=True)

# %%
datetime = df[df['Close'] == df['Close'].max()]['date'].values
high = round(df['Close'].max())

# %%
datetime
# Out:
# array(['2022-01-03T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
high
# Out:
# 181

# %%
fig, ax = plt.subplots(figsize=(10,8), facecolor='green')
ax.plot(df['date'], df['Close'], color='#0f2113')
ax.set_xlabel("Date", fontsize=15)
ax.set_ylabel("Daily closing stock price", fontsize=15)
ax.set_title('All time high of Apple', fontsize=15)
ax.annotate(f"All time high\nprice during\n23year period\nwas ${high}", xy=(datetime, high),xytext=(datetime,high-100),bbox=dict(boxstyle="round",facecolor='#f5d3bf', edgecolor='#d0d5db'),arrowprops=dict(facecolor='#f0190a',headlength=20, shrink=0.1))
plt.show()
fig.savefig('Highest_price.png')

# %%
data.Dividends.value_counts()

# %%
data['Stock Splits'].value_counts()

# %% [markdown]
# ## Checking today's worth when you invested 100 dollars at 1998

# %%
df['returns'] = df['Close'].pct_change()

# calculate cumulative returns
df['cumulative_returns'] = (1+ df['returns']).cumprod()

# %%
df
# Out:
#            date        Open        High         Low       Close     Volume  \
# 0    1998-01-26    0.147936    0.148888    0.143180    0.147936  146440000
# 1    1998-01-27    0.146034    0.149839    0.144607    0.145558  112235200
# 2    1998-01-28    0.146034    0.147461    0.141753    0.146034  151121600
# 3    1998-01-29    0.144131    0.145558    0.140802    0.140802  211881600
# 4    1998-01-30    0.139374    0.143655    0.138898    0.139374  162444800
# ...         ...         ...         ...         ...         ...        ...
# 6287 2023-01-19  134.080002  136.250000  133.770004  135.270004   58280400
# 6288 2023-01-20  135.279999  138.020004  134.220001  137.869995   79972200
# 6289 2023-01-23  138.119995  143.320007  137.899994  141.110001   81760300
# 6290 2023-01-24  140.309998  143.160004  140.300003  142.529999   66435100
# 6291 2023-01-25  140.889999  142.429993  138.809998  141.860001   65652500
#
#       Dividends  Stock Splits   returns  cumulative_returns
# 0           0.0             0       NaN                 NaN
# 1           0.0             0 -0.016076            0.983924
# 2           0.0             0  0.003268            0.987139
# 3           0.0             0 -0.035828            0.951771
# 4           0.0             0 -0.010140            0.942120
# ...         ...           ...       ...                 ...
# 6287        0.0             0  0.000444          914.380073
# 6288        0.0             0  0.019221          931.955143
# 6289        0.0             0  0.023500          953.856499
# 6290        0.0             0  0.010063          963.455212
# 6291        0.0             0 -0.004701          958.926248
#
# [6292 rows x 10 columns]

# %%
df['investment'] = 100 * (1 + df['cumulative_returns'])

# %%
plt.plot(df['investment'])
plt.xlabel('Time')
plt.ylabel('Investment Amount')
plt.title('Investment over Time')
plt.show()

# %%
datetime = df[df['investment'] == df['investment'].max()]['date'].values
high = round(df['investment'].max())

# %%
fig, ax = plt.subplots(figsize=(15,5), facecolor='green')
ax.plot(df['date'], df['investment'], color='green')
ax.set_xlabel("Date", fontsize=15)
ax.set_ylabel("Daily Returns", fontsize=15)
ax.set_title('Return on investment', fontsize=18)
ax.annotate(f"If you invested 100\nin 1998 price would be\n ${high}", xy=(datetime, high),xytext=(datetime,high-100),bbox=dict(boxstyle="round",facecolor='#f5d3bf', edgecolor='#d0d5db'),arrowprops=dict(facecolor='#f0190a',headlength=5, shrink=10))
plt.show()
fig.savefig('Return_all_time.png')

# %% [markdown]
# If you invested 100$ it would be worth 122,423 in 2023.

# %% [markdown]
# ### All-time high

# %%
high= data.copy()
high.reset_index(inplace=True)
high=high.loc[(high['date']>='2022-01-03')].copy()
high
# Out:
#            date        Open        High         Low       Close     Volume  \
# 6025 2022-01-03  176.803859  181.824722  176.684557  180.959732  104487900
# 6026 2022-01-04  181.576172  181.884380  178.086416  178.663071   99310400
# 6027 2022-01-05  178.573600  179.130366  173.632277  173.910660   94537600
# 6028 2022-01-06  171.703465  174.288468  170.649584  171.007507   96904000
# 6029 2022-01-07  171.892360  173.135147  170.043092  171.176514   86709100
# ...         ...         ...         ...         ...         ...        ...
# 6287 2023-01-19  134.080002  136.250000  133.770004  135.270004   58280400
# 6288 2023-01-20  135.279999  138.020004  134.220001  137.869995   79972200
# 6289 2023-01-23  138.119995  143.320007  137.899994  141.110001   81760300
# 6290 2023-01-24  140.309998  143.160004  140.300003  142.529999   66435100
# 6291 2023-01-25  140.889999  142.429993  138.809998  141.860001   65652500
#
#       Dividends  Stock Splits
# 6025        0.0             0
# 6026        0.0             0
# 6027        0.0             0
# 6028        0.0             0
# 6029        0.0             0
# ...         ...           ...
# 6287        0.0             0
# 6288        0.0             0
# 6289        0.0             0
# 6290        0.0             0
# 6291        0.0             0
#
# [267 rows x 8 columns]

# %%
all_time_high = high["Close"].max()

# %%
all_time_high_row = high[high["Close"] == all_time_high]

# %%
all_time_high_date = high["date"].values[0]

# %%
last_row = high.iloc[-1]

# %%
investment_return = (last_row["Close"] / all_time_high) * 100 - 100

# %%
high['ROI'] = (high['Close'] - all_time_high) / all_time_high * 100

# %%
high
# Out:
#            date        Open        High         Low       Close     Volume  \
# 6025 2022-01-03  176.803859  181.824722  176.684557  180.959732  104487900
# 6026 2022-01-04  181.576172  181.884380  178.086416  178.663071   99310400
# 6027 2022-01-05  178.573600  179.130366  173.632277  173.910660   94537600
# 6028 2022-01-06  171.703465  174.288468  170.649584  171.007507   96904000
# 6029 2022-01-07  171.892360  173.135147  170.043092  171.176514   86709100
# ...         ...         ...         ...         ...         ...        ...
# 6287 2023-01-19  134.080002  136.250000  133.770004  135.270004   58280400
# 6288 2023-01-20  135.279999  138.020004  134.220001  137.869995   79972200
# 6289 2023-01-23  138.119995  143.320007  137.899994  141.110001   81760300
# 6290 2023-01-24  140.309998  143.160004  140.300003  142.529999   66435100
# 6291 2023-01-25  140.889999  142.429993  138.809998  141.860001   65652500
#
#       Dividends  Stock Splits        ROI
# 6025        0.0             0   0.000000
# 6026        0.0             0  -1.269156
# 6027        0.0             0  -3.895382
# 6028        0.0             0  -5.499690
# 6029        0.0             0  -5.406296
# ...         ...           ...        ...
# 6287        0.0             0 -25.248561
# 6288        0.0             0 -23.811782
# 6289        0.0             0 -22.021325
# 6290        0.0             0 -21.236621
# 6291        0.0             0 -21.606869
#
# [267 rows x 9 columns]

# %%
datetime = high[high['ROI'] == high['ROI'].min()]['date'].values
higher = round(high['ROI'].min())

# %%
datetime,higher
# Out:
# (array(['2023-01-05T00:00:00.000000000'], dtype='datetime64[ns]'), -31)

# %%
fig, ax = plt.subplots(figsize=(15,5), facecolor='red')
ax.plot(high['date'], high['ROI'], color='red')
ax.set_xlabel("Date", fontsize=15)
ax.set_ylabel("Daily closing stock price", fontsize=15)
ax.set_title('Return on investment when invested during high period', fontsize=20)
ax.annotate(f"If you invested $100\n during higher period\n you would lose\n ${higher}", xy=(datetime, higher),xytext=(datetime,higher+10),bbox=dict(boxstyle="round",facecolor='#f5d3bf', edgecolor='#d0d5db'),arrowprops=dict(facecolor='#f0190a',headlength=5, shrink=100))

fig.savefig('Loss.png')
# Out:
# (array([18993.]), array([19358.]))

# %%
print(f"If you invested $100 in Apple stock on {all_time_high_date} when the stock was at its all-time high of ${all_time_high}, your investment would be worth ${(100 + investment_return):.2f} as of {last_row['date']}")

# %% [markdown]
# ## If you invested 100 in 1998 what would be the money in 2023?

# %%
d=data.copy()
d.reset_index(inplace=True)
d

# %%
start_index = d[d['date'] == '1998-01-26'].index[0]
start_index

# %%
end_index= d.loc[d['date'] == '2023-01-25','Close'].index[0]
end_index

# %%
start_price = d.loc[start_index, 'Close']
end_price = d.loc[end_index, 'Close']
start_price,end_price

# %%
return_on_investment = (end_price * 100 / start_price) - 100

# %%
print("If you invested $100 in Apple stock in 1998, your return on investment would be {:.2f}",(return_on_investment))

# %% [markdown]
# ## Checking the worth of investment when  the price of Apple was all-time high

# %%
d[d['Close']>180 ]

# %%
new_high= d.loc[d['date'] == '2022-01-03'].index[0]
new_high = d.loc[new_high, 'Close']
start_price, new_high

# %%
return_on_investment_high = (new_high* 100 / start_price) - 100

# %%
print("If you invested $100 in Apple stock in 1998, your return during higher period would be  {:.2f}".format(return_on_investment_high))

# %% [markdown]
# ## What if you invested during all-time high?

# %%
high_invest=d.loc[d['date'] == '2022-01-03'].index[0]

# %%
high_invest = d.loc[high_invest, 'Close']

# %%
end_return= d.loc[d['date'] == '2023-01-25','Close'].index[0]
end_return=d.loc[end_return, 'Close']
end_return

# %%
return_on_investment_high = (end_return* 100 / high_invest) - 100

# %%
print("If you invested $100 in Apple stock when stock was high, your return during higher period would be  {:.2f}".format(return_on_investment_high))

# %% [markdown]
# ### If you invested during the all time high you would loose the money now.

# %% [markdown]
# ## Old

# %%
low=data[(data['Close']>60) & (data['Close']<120)]

# %%
low.reset_index(inplace=True)

# %%
low['returns'] = low['Close'].pct_change()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11904\1885527132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low['returns'] = low['Close'].pct_change()

# %%
fig, ax = plt.subplots(figsize=(5,5), facecolor='green')
ax.plot(low['date'], low['returns'], color='green')
ax.set_xlabel("Date", fontsize=15)
ax.set_ylabel("Daily closing stock price", fontsize=15)
#ax.annotate(f"If you invested 100\nin during high price would be\n ${high}", xy=(datetime, high),xytext=(datetime,high-35),bbox=dict(boxstyle="round",facecolor='#f5d3bf', edgecolor='#d0d5db'),arrowprops=dict(facecolor='#f0190a',headlength=5, shrink=10))
plt.show()

# %% [markdown]
# ## Daily Returns

# %%
daily_returns=data.copy()

# %%
daily_returns['daily_returns'] = daily_returns['Close'].pct_change()

# %%
daily_returns[daily_returns['daily_returns']==daily_returns['daily_returns'].max()]['daily_returns']
# Out:
# date
# 1999-10-14    0.142996
# Name: daily_returns, dtype: float64

# %%
daily_returns[daily_returns['daily_returns']==daily_returns['daily_returns'].min()]['daily_returns']
# Out:
# date
# 2000-09-29   -0.518692
# Name: daily_returns, dtype: float64

# %%
plt.figure(figsize=(15,5))
daily_returns['daily_returns'].plot()
plt.xlabel("Date")
plt.ylabel("Percent")
plt.title("Apple Stock Daily Returns",fontsize= 15 )
# Out:
# Text(0.5, 1.0, 'Apple Stock Daily Returns')

# %%
sns.set_style('whitegrid')
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
sns.histplot(data= daily_returns['daily_returns'], bins=60)
ax1.set_xlabel("Daily returns %")
ax1.set_ylabel("Percent")
ax1.set_title("Apple Stock Daily Returns Percentage",fontsize= 15 )
ax1.text(-0.18,60,"Extreme Low\n Returns",fontsize= 12)
ax1.text(0.09,60,"Extreme High\n Returns", fontsize= 12)
plt.show()

# %%
volume= data.copy()
volume.reset_index(inplace=True)
volume
# Out:
#            date        Open        High         Low       Close     Volume  \
# 0    1998-01-26    0.147936    0.148888    0.143180    0.147936  146440000
# 1    1998-01-27    0.146034    0.149839    0.144607    0.145558  112235200
# 2    1998-01-28    0.146034    0.147461    0.141753    0.146034  151121600
# 3    1998-01-29    0.144131    0.145558    0.140802    0.140802  211881600
# 4    1998-01-30    0.139374    0.143655    0.138898    0.139374  162444800
# ...         ...         ...         ...         ...         ...        ...
# 6287 2023-01-19  134.080002  136.250000  133.770004  135.270004   58280400
# 6288 2023-01-20  135.279999  138.020004  134.220001  137.869995   79972200
# 6289 2023-01-23  138.119995  143.320007  137.899994  141.110001   81760300
# 6290 2023-01-24  140.309998  143.160004  140.300003  142.529999   66435100
# 6291 2023-01-25  140.889999  142.429993  138.809998  141.860001   65652500
#
#       Dividends  Stock Splits
# 0           0.0             0
# 1           0.0             0
# 2           0.0             0
# 3           0.0             0
# 4           0.0             0
# ...         ...           ...
# 6287        0.0             0
# 6288        0.0             0
# 6289        0.0             0
# 6290        0.0             0
# 6291        0.0             0
#
# [6292 rows x 8 columns]

# %%
max_x= volume['date'].max()
max_y= volume['Volume'].max()

min_x= volume['date'].min()
min_y= volume['Volume'].min()

mean_x= volume['date'].mean()
mean_y= volume['Volume'].mean()

# %%
fig, ax = plt.subplots(figsize=(20,6), facecolor='#4bd659')
ax.plot(volume['date'], volume['Volume'], color='#283954')
ax.axhline(y=volume['Volume'].max(), linestyle='--', lw=2.2, color='green')
ax.axhline(y=volume['Volume'].min(), linestyle='--',lw=2.2, color='red')
ax.axhline(y=volume['Volume'].mean(), linestyle='--',lw=2.8, color='yellow')
ax.annotate(f"Average trade volume {round(volume['Volume'].mean(),2)}", xy=(mean_x,mean_y), xytext=(mean_x,mean_y-1000),bbox=dict(boxstyle="round",facecolor='#e8e0ba', edgecolor='#d0d5db'))
ax.annotate(f"Maximum trade volume {round(volume['Volume'].max(),2)}", xy=(max_x,max_y),xytext=(max_x,max_y),bbox=dict(boxstyle="round",facecolor='#e8e0ba', edgecolor='#d0d5db') )
ax.annotate(f"Minimum trade volume {round(volume['Volume'].min(),2)}", xy=(min_x,min_y),xytext=(min_x,min_y+100000),bbox=dict(boxstyle="round",facecolor='#e8e0ba', edgecolor='#d0d5db'))
ax.set_title(f"Maximum, Minimum & Average Trade Volume of Apple(1998-2023)")
ax.set_xlabel('Date')
ax.set_ylabel('Volume')
fig.savefig('Volume-traded.png')

# %%
mean_x
# Out:
# Timestamp('2010-07-26 08:36:46.230133504')

# %% [markdown]
# ## Moving average

# %%
ma=data.loc[data['Close']>140].copy()

# %%
ma
# Out:
#                   Open        High         Low       Close     Volume  \
# date
# 2021-01-25  141.372931  143.368959  134.920375  141.224701  157611700
# 2021-01-26  141.896621  142.588314  139.693062  141.461838   98390600
# 2021-01-27  141.728622  142.588312  138.744456  140.374878  140843800
# 2021-07-06  138.850775  141.903952  138.850775  140.783798  108181800
# 2021-07-07  142.290551  143.628806  141.418222  143.311600  104911600
# ...                ...         ...         ...         ...        ...
# 2022-12-13  149.500000  149.970001  144.240005  145.470001   93886200
# 2022-12-14  145.350006  146.660004  141.160004  143.210007   82291200
# 2023-01-23  138.119995  143.320007  137.899994  141.110001   81760300
# 2023-01-24  140.309998  143.160004  140.300003  142.529999   66435100
# 2023-01-25  140.889999  142.429993  138.809998  141.860001   65652500
#
#             Dividends  Stock Splits
# date
# 2021-01-25        0.0             0
# 2021-01-26        0.0             0
# 2021-01-27        0.0             0
# 2021-07-06        0.0             0
# 2021-07-07        0.0             0
# ...               ...           ...
# 2022-12-13        0.0             0
# 2022-12-14        0.0             0
# 2023-01-23        0.0             0
# 2023-01-24        0.0             0
# 2023-01-25        0.0             0
#
# [344 rows x 7 columns]

# %%
ma['ma_30']=ma['Close'].rolling(30).mean()

# %%
fig, ax = plt.subplots(figsize=(15,5), facecolor='purple')
ax.plot(ma[['Close','ma_30']].dropna())
ax.set_xlabel("Date", fontsize=15)
ax.set_ylabel("Daily closing stock price", fontsize=15)
ax.set_title('30 Day Moving Average', fontsize=20)

fig.savefig('30_day_moving_average.png')

# %%
ma['exp_30']=ma['Close'].ewm(span=30).mean()

# %%
ma[['Close','exp_30']].dropna().plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## Hypothesis Testing

# %%
data
# Out:
#                   Open        High         Low       Close     Volume  \
# date
# 1998-01-26    0.147936    0.148888    0.143180    0.147936  146440000
# 1998-01-27    0.146034    0.149839    0.144607    0.145558  112235200
# 1998-01-28    0.146034    0.147461    0.141753    0.146034  151121600
# 1998-01-29    0.144131    0.145558    0.140802    0.140802  211881600
# 1998-01-30    0.139374    0.143655    0.138898    0.139374  162444800
# ...                ...         ...         ...         ...        ...
# 2023-01-19  134.080002  136.250000  133.770004  135.270004   58280400
# 2023-01-20  135.279999  138.020004  134.220001  137.869995   79972200
# 2023-01-23  138.119995  143.320007  137.899994  141.110001   81760300
# 2023-01-24  140.309998  143.160004  140.300003  142.529999   66435100
# 2023-01-25  140.889999  142.429993  138.809998  141.860001   65652500
#
#             Dividends  Stock Splits
# date
# 1998-01-26        0.0             0
# 1998-01-27        0.0             0
# 1998-01-28        0.0             0
# 1998-01-29        0.0             0
# 1998-01-30        0.0             0
# ...               ...           ...
# 2023-01-19        0.0             0
# 2023-01-20        0.0             0
# 2023-01-23        0.0             0
# 2023-01-24        0.0             0
# 2023-01-25        0.0             0
#
# [6292 rows x 7 columns]

# %%
null_hypothesis = {
    'H0': "There is no significant difference between closing price and volume traded for Apple stock."
    , 'H1': "There is significant differnce between closing price and volume traded for Apple stock."}

# %%
import math

from scipy import stats

# %%
alpha=0.05

# %%
def print_sig(p_value, alpha):
    if p_value < alpha:
        print("We reject our null hypothesis.")
        print(null_hypothesis['H1'])
    elif p_value > alpha:
        print("We fail to reject our null hypothesis.")
        print(null_hypothesis['H0'])
    else:
        print("Our test is inconclusive.")

# %%
t2, p2 = stats.ttest_ind(data.Close,data.Volume)
                    
print("t = " + str(t2))
print("p = " + str(p2))
print_sig(p2, alpha)
# Out:
# t = -86.42771967045731
# p = 0.0
# We reject our null hypothesis.
# There is significant differnce between closing price and volume traded for Apple stock.

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
df_close = data[['Close']]
df_volume = data[['Volume']]

# %%
scaler = StandardScaler()

# %%
standardized_close = scaler.fit_transform(df_close)

# %%
standardized_volume = scaler.fit_transform(df_volume)

# %%
df_standardized_close = pd.DataFrame(standardized_close, columns=['Close'])
df_standardized_volume = pd.DataFrame(standardized_volume, columns=['Volume'])

# %%
df_merged = pd.concat([df_standardized_close, df_standardized_volume], axis=1)
df_merged
# Out:
#          Close    Volume
# 0    -0.630607 -0.709631
# 1    -0.630663 -0.798398
# 2    -0.630652 -0.697481
# 3    -0.630776 -0.539800
# 4    -0.630809 -0.668096
# ...        ...       ...
# 6287  2.563112 -0.938419
# 6288  2.624564 -0.882125
# 6289  2.701145 -0.877485
# 6290  2.734707 -0.917256
# 6291  2.718871 -0.919287
#
# [6292 rows x 2 columns]

# %%
t2, p2 = stats.ttest_ind(df_merged.Close,df_merged.Volume)
                    
print("t = " + str(t2))
print("p = " + str(p2))
print_sig(p2, alpha)
# Out:
# t = -6.080195836366001e-15
# p = 0.9999999999999951
# We fail to reject our null hypothesis.
# There is no significant difference between closing price and volume traded for Apple stock.

# %% [markdown]
# ## Model- Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %%
data.tail(2)
# Out:
#                   Open        High         Low       Close    Volume  \
# date
# 2023-01-24  140.309998  143.160004  140.300003  142.529999  66435100
# 2023-01-25  140.889999  142.429993  138.809998  141.860001  65652500
#
#             Dividends  Stock Splits
# date
# 2023-01-24        0.0             0
# 2023-01-25        0.0             0

# %%
y=data['Close']

# %%
X= data.drop(columns = ['Close'], axis = 1)

# %%
X
# Out:
#                   Open        High         Low     Volume  Dividends  \
# date
# 1998-01-26    0.147936    0.148888    0.143180  146440000        0.0
# 1998-01-27    0.146034    0.149839    0.144607  112235200        0.0
# 1998-01-28    0.146034    0.147461    0.141753  151121600        0.0
# 1998-01-29    0.144131    0.145558    0.140802  211881600        0.0
# 1998-01-30    0.139374    0.143655    0.138898  162444800        0.0
# ...                ...         ...         ...        ...        ...
# 2023-01-19  134.080002  136.250000  133.770004   58280400        0.0
# 2023-01-20  135.279999  138.020004  134.220001   79972200        0.0
# 2023-01-23  138.119995  143.320007  137.899994   81760300        0.0
# 2023-01-24  140.309998  143.160004  140.300003   66435100        0.0
# 2023-01-25  140.889999  142.429993  138.809998   65652500        0.0
#
#             Stock Splits
# date
# 1998-01-26             0
# 1998-01-27             0
# 1998-01-28             0
# 1998-01-29             0
# 1998-01-30             0
# ...                  ...
# 2023-01-19             0
# 2023-01-20             0
# 2023-01-23             0
# 2023-01-24             0
# 2023-01-25             0
#
# [6292 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
linear= LinearRegression()

# %%
linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear.score(X_test,y_test)
# Out:
# 0.9999344528233719

# %% [markdown]
# Cross-validation

# %%
scores= cross_val_score(linear, X, y, cv=10)

# %%
scores.mean()
# Out:
# 0.9988331421657722

# %%
y_preds = linear.predict(X_test)
y_preds
# Out:
# array([  1.12875566, 126.29977245,  17.21423153, ...,   3.61743408,
#         30.42765236,   0.35087637])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_test, y_preds, squared=True)
# Out:
# 0.11913299074239352

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_preds)
print(f"R-squared: ", r2)
# Out:
# R-squared:  0.9999344528233719

# %%
n = X_test.shape[0]
p = X_test.shape[1]
adj_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)
adj_r2
# Out:
# 0.9999342437414688

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import Lasso, LassoCV

# %%
alphas = np.logspace(-6, 6, 200)
lasso_cv = LassoCV(alphas = alphas, cv = 10, max_iter = 100000,)
lasso_cv.fit(X_train, y_train)
# Out:
# LassoCV(alphas=array([1.00000000e-06, 1.14895100e-06, 1.32008840e-06, 1.51671689e-06,
#        1.74263339e-06, 2.00220037e-06, 2.30043012e-06, 2.64308149e-06,
#        3.03677112e-06, 3.48910121e-06, 4.00880633e-06, 4.60592204e-06,
#        5.29197874e-06, 6.08022426e-06, 6.98587975e-06, 8.02643352e-06,
#        9.22197882e-06, 1.05956018e-05, 1.21738273e-05, 1.39871310e-05,
#        1.60705282e-05, 1.84642494e-0...
#        4.10265811e+04, 4.71375313e+04, 5.41587138e+04, 6.22257084e+04,
#        7.14942899e+04, 8.21434358e+04, 9.43787828e+04, 1.08436597e+05,
#        1.24588336e+05, 1.43145894e+05, 1.64467618e+05, 1.88965234e+05,
#        2.17111795e+05, 2.49450814e+05, 2.86606762e+05, 3.29297126e+05,
#        3.78346262e+05, 4.34701316e+05, 4.99450512e+05, 5.73844165e+05,
#        6.59318827e+05, 7.57525026e+05, 8.70359136e+05, 1.00000000e+06]),
#         cv=10, max_iter=100000)

# %%
lasso_cv.score(X_test,y_test)
# Out:
# 0.9998905054151654

# %%
alpha=lasso_cv.alpha_
alpha
# Out:
# 1e-06

# %%
lasso=Lasso(alpha=alpha)
lasso.fit(X_train, y_train)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.174e+03, tolerance: 7.831e+02
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=1e-06)

# %%
lasso.score(X_test, y_test)
# Out:
# 0.9996499380775152

# %%
y_pred = lasso.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.6362428698833162

# %%
r2 = r2_score(y_test, y_pred)
print("R^2:", r2)
# Out:
# R^2: 0.9996499380775152

# %% [markdown]
# ## Ridge

# %%
from sklearn.linear_model import Ridge, RidgeCV

# %%
alphas = np.logspace(-6, 6, 200)
ridge_cv = RidgeCV(alphas = alphas, cv = 10)
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([1.00000000e-06, 1.14895100e-06, 1.32008840e-06, 1.51671689e-06,
#        1.74263339e-06, 2.00220037e-06, 2.30043012e-06, 2.64308149e-06,
#        3.03677112e-06, 3.48910121e-06, 4.00880633e-06, 4.60592204e-06,
#        5.29197874e-06, 6.08022426e-06, 6.98587975e-06, 8.02643352e-06,
#        9.22197882e-06, 1.05956018e-05, 1.21738273e-05, 1.39871310e-05,
#        1.60705282e-05, 1.84642494e-0...
#        4.10265811e+04, 4.71375313e+04, 5.41587138e+04, 6.22257084e+04,
#        7.14942899e+04, 8.21434358e+04, 9.43787828e+04, 1.08436597e+05,
#        1.24588336e+05, 1.43145894e+05, 1.64467618e+05, 1.88965234e+05,
#        2.17111795e+05, 2.49450814e+05, 2.86606762e+05, 3.29297126e+05,
#        3.78346262e+05, 4.34701316e+05, 4.99450512e+05, 5.73844165e+05,
#        6.59318827e+05, 7.57525026e+05, 8.70359136e+05, 1.00000000e+06]),
#         cv=10)

# %%
ridge_cv.score(X_test,y_test)
# Out:
# 0.9999341770126612

# %%
alpha = ridge_cv.alpha_
alpha
# Out:
# 0.002736439997074669

# %%
ridge = Ridge(alpha = ridge_cv.alpha_)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.002736439997074669)

# %%
ridge.score(X_test, y_test)
# Out:
# 0.9999341770126612

# %%
y_pred = ridge.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.11963428090522922

# %%
r2 = r2_score(y_test, y_pred)
print("R^2:", r2)
# Out:
# R^2: 0.9999341770126612

# %%
score= cross_val_score(ridge,X,y,cv=10)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.34598e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.3691e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.40075e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.76366e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.55811e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.27278e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.13668e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=1.09161e-21): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=9.36241e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.99907e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %%
score.mean()
# Out:
# 0.9988330801053709

# %% [markdown]
# ## Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
alphas = np.logspace(-5, 5, 100)

# %%
grid = GridSearchCV(Ridge(), param_grid={'alpha': alphas}, cv=10)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': array([1.00000000e-05, 1.26185688e-05, 1.59228279e-05, 2.00923300e-05,
#        2.53536449e-05, 3.19926714e-05, 4.03701726e-05, 5.09413801e-05,
#        6.42807312e-05, 8.11130831e-05, 1.02353102e-04, 1.29154967e-04,
#        1.62975083e-04, 2.05651231e-04, 2.59502421e-04, 3.27454916e-04,
#        4.13201240e-04, 5.21400829e-04, 6.57933225e-04, 8...
#        4.75081016e+02, 5.99484250e+02, 7.56463328e+02, 9.54548457e+02,
#        1.20450354e+03, 1.51991108e+03, 1.91791026e+03, 2.42012826e+03,
#        3.05385551e+03, 3.85352859e+03, 4.86260158e+03, 6.13590727e+03,
#        7.74263683e+03, 9.77009957e+03, 1.23284674e+04, 1.55567614e+04,
#        1.96304065e+04, 2.47707636e+04, 3.12571585e+04, 3.94420606e+04,
#        4.97702356e+04, 6.28029144e+04, 7.92482898e+04, 1.00000000e+05])})

# %%
grid.score(X_test, y_test)
# Out:
# 0.9999341852992041

# %%
alphas
# Out:
# array([1.00000000e-05, 1.26185688e-05, 1.59228279e-05, 2.00923300e-05,
#        2.53536449e-05, 3.19926714e-05, 4.03701726e-05, 5.09413801e-05,
#        6.42807312e-05, 8.11130831e-05, 1.02353102e-04, 1.29154967e-04,
#        1.62975083e-04, 2.05651231e-04, 2.59502421e-04, 3.27454916e-04,
#        4.13201240e-04, 5.21400829e-04, 6.57933225e-04, 8.30217568e-04,
#        1.04761575e-03, 1.32194115e-03, 1.66810054e-03, 2.10490414e-03,
#        2.65608778e-03, 3.35160265e-03, 4.22924287e-03, 5.33669923e-03,
#        6.73415066e-03, 8.49753436e-03, 1.07226722e-02, 1.35304777e-02,
#        1.70735265e-02, 2.15443469e-02, 2.71858824e-02, 3.43046929e-02,
#        4.32876128e-02, 5.46227722e-02, 6.89261210e-02, 8.69749003e-02,
#        1.09749877e-01, 1.38488637e-01, 1.74752840e-01, 2.20513074e-01,
#        2.78255940e-01, 3.51119173e-01, 4.43062146e-01, 5.59081018e-01,
#        7.05480231e-01, 8.90215085e-01, 1.12332403e+00, 1.41747416e+00,
#        1.78864953e+00, 2.25701972e+00, 2.84803587e+00, 3.59381366e+00,
#        4.53487851e+00, 5.72236766e+00, 7.22080902e+00, 9.11162756e+00,
#        1.14975700e+01, 1.45082878e+01, 1.83073828e+01, 2.31012970e+01,
#        2.91505306e+01, 3.67837977e+01, 4.64158883e+01, 5.85702082e+01,
#        7.39072203e+01, 9.32603347e+01, 1.17681195e+02, 1.48496826e+02,
#        1.87381742e+02, 2.36448941e+02, 2.98364724e+02, 3.76493581e+02,
#        4.75081016e+02, 5.99484250e+02, 7.56463328e+02, 9.54548457e+02,
#        1.20450354e+03, 1.51991108e+03, 1.91791026e+03, 2.42012826e+03,
#        3.05385551e+03, 3.85352859e+03, 4.86260158e+03, 6.13590727e+03,
#        7.74263683e+03, 9.77009957e+03, 1.23284674e+04, 1.55567614e+04,
#        1.96304065e+04, 2.47707636e+04, 3.12571585e+04, 3.94420606e+04,
#        4.97702356e+04, 6.28029144e+04, 7.92482898e+04, 1.00000000e+05])

# %%
grid.best_params_['alpha']
# Out:
# 0.0026560877829466868

# %%
data.corr().T
# Out:
#                   Open      High       Low     Close    Volume  Dividends  \
# Open          1.000000  0.999930  0.999912  0.999813 -0.416959   0.082621
# High          0.999930  1.000000  0.999898  0.999912 -0.416183   0.082066
# Low           0.999912  0.999898  1.000000  0.999915 -0.418064   0.082378
# Close         0.999813  0.999912  0.999915  1.000000 -0.417129   0.082302
# Volume       -0.416959 -0.416183 -0.418064 -0.417129  1.000000  -0.054751
# Dividends     0.082621  0.082066  0.082378  0.082302 -0.054751   1.000000
# Stock Splits  0.008730  0.009002  0.008722  0.008979 -0.003832  -0.001753
#
#               Stock Splits
# Open              0.008730
# High              0.009002
# Low               0.008722
# Close             0.008979
# Volume           -0.003832
# Dividends        -0.001753
# Stock Splits      1.000000

# %% [markdown]
# ## 3 features

# %%
X=data[['Volume']]

# %%
y=data['Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.09148001],
#        [-0.74177192],
#        [ 3.64600806],
#        ...,
#        [-0.72215113],
#        [-0.88919389],
#        [-0.35281559]])

# %%
linear1= LinearRegression()

# %%
linear1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear1.score(X_test,y_test)
# Out:
# 0.15829525623534635

# %%
X=data[['Volume','Stock Splits', 'Dividends']]
y=data['Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
linear2= LinearRegression()

# %%
linear2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear2.score(X_test,y_test)
# Out:
# 0.16526834619231445

# %%
X=data[['Volume','Stock Splits', 'Dividends','Open']]
y=data['Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
linear3= LinearRegression()

# %%
linear3.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear3.score(X_test,y_test)
# Out:
# 0.9995803893825792

# %% [markdown]
# ## Logistic Regression

# %%
log=data.copy()
log.head(2)
# Out:
#                 Open      High       Low     Close     Volume  Dividends  \
# date
# 1998-01-26  0.147936  0.148888  0.143180  0.147936  146440000        0.0
# 1998-01-27  0.146034  0.149839  0.144607  0.145558  112235200        0.0
#
#             Stock Splits
# date
# 1998-01-26             0
# 1998-01-27             0

# %%
a=log.loc[log['Close']>120,'Close']

# %%
a.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
new_df= log.loc[log['Close']>120].copy()

# %%
new_df['Close'] = np.where(new_df['Close'] >= 145, 1, 0)

# %%
new_df.head(2)
# Out:
#                   Open        High         Low  Close     Volume  Dividends  \
# date
# 2020-08-21  117.644839  123.173817  117.632511      0  338054800        0.0
# 2020-08-24  126.951866  127.038188  122.256435      0  345937600        0.0
#
#             Stock Splits
# date
# 2020-08-21             0
# 2020-08-24             0

# %%
new_df.Close.value_counts()
# Out:
# 1    277
# 0    262
# Name: Close, dtype: int64

# %% [markdown]
# Selecting the closing price above 120 and creating a new df and then converting linear regression to logistic regression wher 1 means to sell and 0 means to buy

# %%
new_df
# Out:
#                   Open        High         Low  Close     Volume  Dividends  \
# date
# 2020-08-21  117.644839  123.173817  117.632511      0  338054800        0.0
# 2020-08-24  126.951866  127.038188  122.256435      0  345937600        0.0
# 2020-08-25  123.006124  123.482077  121.383432      0  211495600        0.0
# 2020-08-26  124.468520  125.270000  123.385903      0  163022400        0.0
# 2020-08-27  125.417967  125.755820  122.152858      0  155552400        0.0
# ...                ...         ...         ...    ...        ...        ...
# 2023-01-19  134.080002  136.250000  133.770004      0   58280400        0.0
# 2023-01-20  135.279999  138.020004  134.220001      0   79972200        0.0
# 2023-01-23  138.119995  143.320007  137.899994      0   81760300        0.0
# 2023-01-24  140.309998  143.160004  140.300003      0   66435100        0.0
# 2023-01-25  140.889999  142.429993  138.809998      0   65652500        0.0
#
#             Stock Splits
# date
# 2020-08-21             0
# 2020-08-24             0
# 2020-08-25             0
# 2020-08-26             0
# 2020-08-27             0
# ...                  ...
# 2023-01-19             0
# 2023-01-20             0
# 2023-01-23             0
# 2023-01-24             0
# 2023-01-25             0
#
# [539 rows x 7 columns]

# %%
X= new_df.drop('Close',axis=1)
X
# Out:
#                   Open        High         Low     Volume  Dividends  \
# date
# 2020-08-21  117.644839  123.173817  117.632511  338054800        0.0
# 2020-08-24  126.951866  127.038188  122.256435  345937600        0.0
# 2020-08-25  123.006124  123.482077  121.383432  211495600        0.0
# 2020-08-26  124.468520  125.270000  123.385903  163022400        0.0
# 2020-08-27  125.417967  125.755820  122.152858  155552400        0.0
# ...                ...         ...         ...        ...        ...
# 2023-01-19  134.080002  136.250000  133.770004   58280400        0.0
# 2023-01-20  135.279999  138.020004  134.220001   79972200        0.0
# 2023-01-23  138.119995  143.320007  137.899994   81760300        0.0
# 2023-01-24  140.309998  143.160004  140.300003   66435100        0.0
# 2023-01-25  140.889999  142.429993  138.809998   65652500        0.0
#
#             Stock Splits
# date
# 2020-08-21             0
# 2020-08-24             0
# 2020-08-25             0
# 2020-08-26             0
# 2020-08-27             0
# ...                  ...
# 2023-01-19             0
# 2023-01-20             0
# 2023-01-23             0
# 2023-01-24             0
# 2023-01-25             0
#
# [539 rows x 6 columns]

# %%
y= new_df['Close']
y
# Out:
# date
# 2020-08-21    0
# 2020-08-24    0
# 2020-08-25    0
# 2020-08-26    0
# 2020-08-27    0
#              ..
# 2023-01-19    0
# 2023-01-20    0
# 2023-01-23    0
# 2023-01-24    0
# 2023-01-25    0
# Name: Close, Length: 539, dtype: int32

# %%
new_df.Close.value_counts()
# Out:
# 1    277
# 0    262
# Name: Close, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=
# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import classification_report

# %%
y_pred = log.predict(X_test)
ac = accuracy_score(y_test,y_pred)
print('Accuracy is: ',ac)
# Out:
# Accuracy is:  0.9691358024691358

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True,fmt="d");
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97        82
#            1       0.95      0.99      0.97        80
#
#     accuracy                           0.97       162
#    macro avg       0.97      0.97      0.97       162
# weighted avg       0.97      0.97      0.97       162

# %% [markdown]
# ## Support Vector Machines

# %%
from sklearn.svm import SVC

# %%
X= new_df.drop('Close',axis=1)
y=new_df['Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.3)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
svc_model = SVC(probability=True)
svc_model.fit(X_train, y_train)
svc_model.score(X_test, y_test)
# Out:
# 0.9629629629629629

# %%
scores=cross_val_score(SVC(),X,y,cv=10)

# %%
scores.mean()
# Out:
# 0.46380153738644303

# %%
y_pred = svc_model.predict(X_test)
ac = accuracy_score(y_test,y_pred)
print('Accuracy is: ',ac)
# Out:
# Accuracy is:  0.9629629629629629

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True,fmt="d");
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96        82
#            1       0.94      0.99      0.96        80
#
#     accuracy                           0.96       162
#    macro avg       0.96      0.96      0.96       162
# weighted avg       0.96      0.96      0.96       162

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
X= new_df.drop('Close',axis=1)
y=new_df['Close']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.3)

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
nb= GaussianNB()

# %%
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
nb.score(X_test,y_test)
# Out:
# 0.9629629629629629

# %%
scores=cross_val_score(nb,X,y,cv=10)

# %%
scores.mean()
# Out:
# 0.4934311670160727

# %%
y_pred = nb.predict(X_test)
ac = accuracy_score(y_test,y_pred)
print('Accuracy is: ',ac)
# Out:
# Accuracy is:  0.9629629629629629

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True,fmt="d");
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96        82
#            1       0.94      0.99      0.96        80
#
#     accuracy                           0.96       162
#    macro avg       0.96      0.96      0.96       162
# weighted avg       0.96      0.96      0.96       162

# %%
preds_log = log.predict_proba(X_test)[:,1]
preds_svc= svc_model.predict_proba(X_test)[:,1]
preds_nb= nb.predict_proba(X_test)[:,1]


fpr, tpr, _ = metrics.roc_curve(y_test, preds_log)
fpr_svc, tpr_svc, _= metrics.roc_curve(y_test, preds_svc)
fpr_nb, tpr_nb, _= metrics.roc_curve(y_test, preds_nb)


roc_auc = metrics.auc(fpr, tpr)
roc_auc1 = metrics.auc(fpr_svc, tpr_svc)
roc_auc2 = metrics.auc(fpr_nb, tpr_nb)


plt.figure(figsize=[10,10])
lw = 2

plt.plot(fpr, tpr, color='darkorange', lw = lw, label = 'Logistic ROC curve (area = %0.2f)' % roc_auc )
plt.plot(fpr_svc, tpr_svc, color='red', lw = lw, label = ' Support Vectors ROC curve (area = %0.2f)' % roc_auc1)
plt.plot(fpr_nb, tpr_nb,  color='blue', lw = lw, label = 'Naive Bayes ROC curve (area = %0.2f)' % roc_auc2)

plt.plot([0, 1], [0, 1], color = 'navy', lw = lw, linestyle = '--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc = "lower right")
plt.show()
